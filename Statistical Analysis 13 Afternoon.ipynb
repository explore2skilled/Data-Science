# %%
import pandas as pd
data=pd.read_csv("data.csv")
data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#to check information of dataset 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
#convert churn features from datatype boolean to int64
data['Churn']=data['Churn'].astype('int64')

# %%
data.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                       int64
# dtype: object

# %%
data['Churn']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
data['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
#find statistical analysis of all numerical features 
round(data.describe(),0)
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count          3333.0     3333.0                 3333.0             3333.0
# mean            101.0      437.0                    8.0              180.0
# std              40.0       42.0                   14.0               54.0
# min               1.0      408.0                    0.0                0.0
# 25%              74.0      408.0                    0.0              144.0
# 50%             101.0      415.0                    0.0              179.0
# 75%             127.0      510.0                   20.0              216.0
# max             243.0      510.0                   51.0              351.0
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count           3333.0            3333.0             3333.0           3333.0
# mean             100.0              31.0              201.0            100.0
# ...

# %%
#statistics of non-numerical features 
data.describe(include='object')
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
#find proportion of churned users 
data['Churn'].value_counts(normalize=True)*100
# Out:
# 0    85.508551
# 1    14.491449
# Name: Churn, dtype: float64

# %%
#sort data by total day charge in descending order 
data.sort_values(by='Total day charge',ascending=False)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
# ...    ...             ...        ...                ...             ...
# 1986    WI              70        415                 No              No
# 2753    OH             134        415                 No              No
# 2736    OK             127        510                 No             Yes
# 1397    VT             101        510                 No              No
# 1345    SD              98        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#sort data with multiple columns 
data.sort_values(by=['Total day charge','Area code'],ascending=False)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
# ...    ...             ...        ...                ...             ...
# 1986    WI              70        415                 No              No
# 2753    OH             134        415                 No              No
# 2736    OK             127        510                 No             Yes
# 1397    VT             101        510                 No              No
# 1345    SD              98        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#indexing & selecting data 
#total proportion of chruned user  for dataset
data['Churn'].mean()*100
# Out:
# 14.491449144914492

# %%
data['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
#find average value of churned users for all numerical features 
data[data['Churn']==1].mean()
# Out:
# <ipython-input-21-28b3d57f8572>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[data['Churn']==1].mean()
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
#find out amount of time spend by churned users during day time 
data[data['Churn']==1]['Total day minutes'].mean()
# Out:
# 206.91407867494814

# %%
#maximum length of international calls among loyal users (Churn == 0) who do not have an international plan
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
data[(data['Churn']==0)& (data['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
import numpy as np
data.apply(np.min)
# Out:
# State                       AK
# Account length               1
# Area code                  408
# International plan          No
# Voice mail plan             No
# Number vmail messages        0
# Total day minutes          0.0
# Total day calls              0
# Total day charge           0.0
# Total eve minutes          0.0
# Total eve calls              0
# Total eve charge           0.0
# Total night minutes       23.2
# Total night calls           33
# Total night charge        1.04
# Total intl minutes         0.0
# Total intl calls             0
# Total intl charge          0.0
# Customer service calls       0
# Churn                        0
# dtype: object

# %%
data[['Total day calls','Total eve calls','Total night calls']].apply(np.min)
# Out:
# Total day calls       0
# Total eve calls       0
# Total night calls    33
# dtype: int64

# %%
data[['Total day calls','Total eve calls','Total night calls']].apply(np.mean)
# Out:
# Total day calls      100.435644
# Total eve calls      100.114311
# Total night calls    100.107711
# dtype: float64

# %%
#how many curned users are there who belongs to state starting "F"
data[data['State'].apply(lambda i:i.startswith('F'))]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 20      FL             147        415                 No              No
# 137     FL              91        510                 No              No
# 159     FL             115        510                 No             Yes
# 214     FL              70        510                Yes              No
# 216     FL              93        415                 No              No
# ...    ...             ...        ...                ...             ...
# 2651    FL             108        510                 No              No
# 2665    FL              85        408                Yes              No
# 2864    FL             153        415                 No              No
# 3010    FL             185        408                 No              No
# 3077    FL             102        408                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#find the values of churn user according to total day minutes , evening minutes , night minutes 
data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].describe()
# Out:
# <ipython-input-31-c00913516581>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].describe()
#       Total day minutes                                                      \
#                   count        mean        std  min      25%    50%     75%
# Churn
# 0                2850.0  175.175754  50.181655  0.0  142.825  177.2  210.30
# 1                 483.0  206.914079  68.997792  0.0  153.250  217.6  265.95
#
#              Total eve minutes              ...                 \
#          max             count        mean  ...     75%    max
# Churn                                       ...
# 0      315.6            2850.0  199.043298  ...  233.20  361.8
# 1      350.8             483.0  212.410145  ...  249.45  363.7
#
#       Total night minutes                                               \
# ...

# %%
data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].value_counts()
# Out:
# <ipython-input-33-e31cf14c4c3f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].value_counts()
# Churn  Total day minutes  Total eve minutes  Total night minutes
# 0      0.0                192.1              168.8                  1
#        207.6              251.6              191.6                  1
#        214.6              96.6               170.7                  1
#                           205.2              134.6                  1
#                           235.1              162.8                  1
#                                                                    ..
# 1      109.0              259.3              182.1                  1
#        109.6              249.3              321.2                  1
#        110.5              208.3              87.4                   1
# ...

# %%
data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].mean()
# Out:
# <ipython-input-38-59b0936b7ee8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].mean()
#        Total day minutes  Total eve minutes  Total night minutes
# Churn
# 0             175.175754         199.043298           200.133193
# 1             206.914079         212.410145           205.231677

# %%
data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].agg([np.mean,np.sum,np.max])
# Out:
# <ipython-input-39-8b3be83ff6df>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['Churn'])['Total day minutes','Total eve minutes','Total night minutes'].agg([np.mean,np.sum,np.max])
#       Total day minutes                  Total eve minutes                   \
#                    mean       sum   amax              mean       sum   amax
# Churn
# 0            175.175754  499250.9  315.6        199.043298  567273.4  361.8
# 1            206.914079   99939.5  350.8        212.410145  102594.1  363.7
#
#       Total night minutes
#                      mean       sum   amax
# Churn
# 0              200.133193  570379.6  395.0
# 1              205.231677   99126.9  354.9

# %%
#how to create summary table 
#crosstable 
#pivottable
pd.crosstab(data['Churn'],data['International plan'])
# Out:
# International plan    No  Yes
# Churn
# 0                   2664  186
# 1                    346  137

# %%
#find the total of churned user who have voice mail plan
pd.crosstab(data['Churn'],data['Voice mail plan'],normalize=False)
# Out:
# Voice mail plan    No  Yes
# Churn
# 0                2008  842
# 1                 403   80

# %%
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#make relationship between total day calls based on churned users having international plan 
data['daycall>100']=(data['Total day calls']>100)

# %%
data
# Out:
#      State  Account length  Area code  International plan Voice mail plan  \
# 0       KS             128        415                   0             Yes
# 1       OH             107        415                   0             Yes
# 2       NJ             137        415                   0              No
# 3       OH              84        408                   1              No
# 4       OK              75        415                   1              No
# ...    ...             ...        ...                 ...             ...
# 3328    AZ             192        415                   0             Yes
# 3329    WV              68        415                   0              No
# 3330    RI              28        510                   0              No
# 3331    CT             184        510                   1              No
# 3332    TN              74        415                   0             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
data['daycall>100']=data['daycall>100'].astype('int64')

# %%
data['International plan']=data['International plan'].map({'No':0,'Yes':1})

# %%
data
# Out:
#      State  Account length  Area code  International plan Voice mail plan  \
# 0       KS             128        415                   0             Yes
# 1       OH             107        415                   0             Yes
# 2       NJ             137        415                   0              No
# 3       OH              84        408                   1              No
# 4       OK              75        415                   1              No
# ...    ...             ...        ...                 ...             ...
# 3328    AZ             192        415                   0             Yes
# 3329    WV              68        415                   0              No
# 3330    RI              28        510                   0              No
# 3331    CT             184        510                   1              No
# 3332    TN              74        415                   0             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
pd.crosstab(data['daycall>100'] & data['International plan'],data['Churn'])
# Out:
# Churn     0    1
# row_0
# 0      2749  412
# 1       101   71

# %%
#visualisation 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#creating graph structure on counting number of churned users having voice mail plan 
sns.countplot(x='Voice mail plan', hue='Churn' , data=data)
# Out:
# <AxesSubplot:xlabel='Voice mail plan', ylabel='count'>

# %%
#create a graph for numbers of customer service calls for the churned users 
sns.countplot(x='Customer service calls',hue='Churn',data=data)
# Out:
# <AxesSubplot:xlabel='Customer service calls', ylabel='count'>

# %%
#create a visual comparing numbers of night calls over day calls 
sns.countplot(x='Total night calls',hue='Total day calls',data=data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-6614a674fff8> in <module>
#       1 #create a visual comparing numbers of night calls over day calls
# ----> 2 sns.countplot(x='Total night calls',hue='Total day calls',data=data)
#
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\Anaconda\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3593         raise ValueError("Cannot pass values for both `x` and `y`")
#    3594
# -> 3595     plotter = _CountPlotter(
#    3596         x, y, hue, data, order, hue_order,
# ...

# %%
data.head(10).groupby(['Total night calls','Total day calls'])['Churn'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Churn'>
